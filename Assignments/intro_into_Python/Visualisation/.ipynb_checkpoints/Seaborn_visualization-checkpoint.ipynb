# %% [markdown]
# # Exploring Seaborn library

# %% [markdown]
# > if there are many values to fit in x axis use g.set_xticklabels(ign_data.index, rotation=45)
#
#
# > different themes  sns.set_style("ticks")
# - "darkgrid"
# - "whitegrid"
# - "dark"
# - "white"
# - "ticks"

# %%
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
spotify_filepath = "data/spotify.csv"

# Read the file into a variable spotify_data
spotify_data = pd.read_csv(spotify_filepath, index_col="Date")
spotify_data.sample(5)
# Out:
#             Shape of You   Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2017-05-06      10555302  21096685.0                 6959582.0  8935434.0
# 2017-12-27       4393658   3463788.0                 2241642.0  2445535.0
# 2017-08-09       5577100  11072469.0                 3679142.0  3810186.0
# 2017-05-22       8306796  19990671.0                 5526221.0  7757136.0
# 2017-11-01       3819439   3662143.0                 1997851.0  2586475.0
#
#             Unforgettable
# Date
# 2017-05-06      4025107.0
# 2017-12-27      2423038.0
# 2017-08-09      6775658.0
# 2017-05-22      4997624.0
# 2017-11-01      3630529.0

# %% [markdown]
# >  Best to show trends over a period of time
#
# ### Line Charts

# %% [markdown]
# - Plot the data

# %%
plt.figure(figsize=(14,6))

sns.lineplot(data=spotify_data)

# %%
# convrt Date to Data time to fix x axis 

import datetime
spotify_data.index = pd.to_datetime(spotify_data.index)
spotify_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 366 entries, 2017-01-06 to 2018-01-09
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Shape of You              366 non-null    int64
#  1   Despacito                 359 non-null    float64
#  2   Something Just Like This  319 non-null    float64
#  3   HUMBLE.                   282 non-null    float64
#  4   Unforgettable             275 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 17.2 KB

# %% [markdown]
# - Plot a subset of the data

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,6))


# Add title
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

# Line chart showing daily global streams of 'Shape of You'
sns.lineplot(data=spotify_data['Shape of You'], label="Shape of You", dashes=False, marker="o")

# Line chart showing daily global streams of 'Despacito'
sns.lineplot(data=spotify_data['Despacito'], label="Despacito",  dashes=False, marker="o")

# %% [markdown]
#  > Relationship: to understand relationships between variables

# %% [markdown]
# ### Bar Chart

# %%
plt.figure(figsize=(14,6))

sns.barplot(x = spotify_data.index.month , y= spotify_data['Shape of You'], color = 'pink')

# %% [markdown]
# ### Heatmaps

# %%
# Heatmap showing average arrival delay for each airline by month
sns.heatmap(data=spotify_data, annot=True)

# %% [markdown]
# Too many y values

# %%
df = pd.read_csv('data/ign_scores.csv', index_col= 0)

# %%
# annot=True - This ensures that the values for each cell appear on the chart
plt.figure(figsize=(9,9))

sns.heatmap(data=df, annot=True)

# %% [markdown]
# ### Scatter plots

# %%
sns.scatterplot(x= spotify_data.index.month , 
                y=spotify_data['Shape of You'])

# %% [markdown]
# - Color-coded scatter plots

# %%
sns.scatterplot(x= spotify_data.index.month , 
                y=spotify_data['Shape of You'],
               hue = spotify_data.index.month)

# %% [markdown]
# ### Regression line
# To double-check the strength of this relationship, you might like to add a regression line,

# %%
sns.regplot(x= spotify_data.index.month , 
                y=spotify_data['Shape of You'])

# %% [markdown]
# ### lmplot
# to add two regression lines

# %% [markdown]
# ### Categorical scatter plots
# Usually, we use scatter plots to highlight the relationship between two continuous variables

# %%
insurance_data = pd.read_csv('data/insurance.csv')

# %%
sns.swarmplot(x=insurance_data['smoker'],
              y=insurance_data['charges'])

# %% [markdown]
# > Distributions: to show the possible values that we can expect to see in a variable,

# %% [markdown]
# ### Histograms

# %%
spotify_data.head()
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
# 2017-01-10      14275628        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN

# %%
sns.distplot(a = spotify_data['Shape of You'], kde=False)

# %% [markdown]
# - 2D histogram

# %%
sns.distplot(a = spotify_data['Shape of You'], kde=False, label="Shape of You")

sns.distplot(a = spotify_data['Despacito'], kde=False, label= "Despacito")

# %% [markdown]
# ### KDE plots

# %%
sns.kdeplot(data = spotify_data['Shape of You'] , shade=True)

# %%
sns.kdeplot(data = spotify_data['Shape of You'] , shade=True, label="Shape of You")

sns.kdeplot(data = spotify_data['Despacito'] , shade=True, label = "Despacito")

# %% [markdown]
# - 2D KDE plots

# %%
sns.jointplot(x=spotify_data.index.month, 
              y=spotify_data['Shape of You'], kind="kde")
